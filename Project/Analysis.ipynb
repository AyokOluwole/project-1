# %% [markdown]
# # Analysis 1 Conclusion - Comparing Population to Death Rate
#
# * Top 5 Cities with Highest Death Registered Rate - HUNTSVILLE, TWEED, PARRY SOUND, RENFREW, PERTH
#
# * Top 5 Cities with Lowest Death Registered Rate - AYLMER, MARATHON, INNISFIL, KING, WASAGA BEACH
#
#
# # Analysis 2 Conclusion- Comparing Population to Health Impacted by Oil Spills
#
# * Top 5 Cities with Highest Health Impacted by Oil Spills - CHAPLEAU, RED LAKE, WIARTON, IROQUOIS FALLS, HEARST
#
# * Top 5 Cities with Lowest Health Impacted by Oil Spills - TORONTO, KITCHENER, KINGSTON, OSHAWA, WELLAND
#
#
# # Analysis 3 Conclusion - Comparing Population to Non-Compliant Facilities for Air Emission
#
# * Top 5 Cities with Highest Non Compliant Air Facilities - SAULT STE. MARIE, KINGSTON, KENORA, SUDBURY, TIMMINS
#
# * Top 5 Cities with Lowest Non Compliant Air Facilities  - TORONTO, LONDON, PETERBOROUGH, WINDSOR, BELLEVILLE
#
#
# # Analysis 4 Conclusion - Comparing Population to Social Assistance Programs Offered
#
# * Top 5 Cities with Highest Social Assistance Programs Offered - ST. CATHARINES, PETERBOROUGH, BRANTFORD, THUNDER BAY, KINGSTON
#
# * Top 5 Cities with Lowest Social Assistance Programs Offered - TORONTO, KITCHENER, OTTAWA, GUELPH, OSHAWA
#
#
# # Analysis 5 Conclusion - Comparing Population to University Enrolment
#
# * Top 5 Cities with Highest University Enrolment - PETERBOROUGH, KINGSTON, GUELPH, LONDON, SUDBURY
#
# * Top 5 Cities with Lowest University Enrolment - TORONTO, SAULT STE. MARIE, OSHAWA, OTTAWA, HEARST

# %%
#Dependies
import pandas as pd
import matplotlib

# %%
#Import Cleaned up Data Files

population_file = "../Project/Resources/Cleaned_Data/Ont_Population.csv"

registered_death_file        = "../Project/Resources/Cleaned_Data/Death_Registration.csv"
social_assistance_file       = "../Project/Resources/Cleaned_Data/Social_Assistance_Programs.csv"
infrastructure_projects_file = "../Project/Resources/Cleaned_Data/Infrastructure_Projects.csv"
university_file              = "../Project/Resources/Cleaned_Data/University_Enrollment.csv"
environment_spills_file      = "../Project/Resources/Cleaned_Data/Environmental_Spills.csv"
air_emission_file            = "../Project/Resources/Cleaned_Data/Air_Emission_Non_Compliant_Facilities.csv"

# %%
#Read the Data Files with Pandas

population_df = pd.read_csv(population_file)

registered_death_df        = pd.read_csv(registered_death_file)
social_assistance_df       = pd.read_csv(social_assistance_file)
infrastructure_projects_df = pd.read_csv(infrastructure_projects_file)
university_df              = pd.read_csv(university_file)
environment_spills_df      = pd.read_csv(environment_spills_file)
air_emission_df            = pd.read_csv(air_emission_file)

# %% [markdown]
# Analysis 1 Conclusion - Comparing Population to Death Rate
#
# Top 5 Cities with Highest Death Registered Rate - HUNTSVILLE, TWEED, PARRY SOUND, RENFREW, PERTH
#
# Top 5 Cities with Lowest Death Registered Rate - AYLMER, MARATHON, INNISFIL, KING, WASAGA BEACH

# %%
#Merge file and get the Percentage

death_analysis = pd.merge(population_df, registered_death_df, on='City')

death_percent = ((death_analysis['Total Deaths Registered']) / (death_analysis['Total Population']))

death_analysis['Percent of Death Registered Compared to Population'] = death_percent.astype(float).map("{:.2%}".format)


death_analysis.head()
# Out:
#    Unnamed: 0       City  Total Population Land area (km2)[2]  \
# 0           0    TORONTO           5647656           1,829.05
# 1           1     OTTAWA           1068821             549.49
# 2           2   HAMILTON            729560             356.03
# 3           3  KITCHENER            522888             296.45
# 4           4     LONDON            423369             244.97
#
#    Total Deaths Registered Percent of Death Registered Compared to Population
# 0                    22131                                              0.39%
# 1                     7706                                              0.72%
# 2                     5854                                              0.80%
# 3                     2453                                              0.47%
# 4                     4340                                              1.03%

# %%
#Sort by Highest Percentage

death_analysis.sort_values(by=["Percent of Death Registered Compared to Population"], ascending=False, inplace=True)

death_analysis.head()
# Out:
#     Unnamed: 0         City  Total Population Land area (km2)[2]  \
# 58          98   HUNTSVILLE              6639               8.73
# 78         237        TWEED              1541                2.5
# 57          97  PARRY SOUND              6788               7.95
# 50          86      RENFREW              8337              12.14
# 59         100        PERTH              6486               9.39
#
#     Total Deaths Registered Percent of Death Registered Compared to Population
# 58                      312                                              4.70%
# 78                       57                                              3.70%
# 57                      237                                              3.49%
# 50                      270                                              3.24%
# 59                      183                                              2.82%

# %%
#Sort by Lowest Percentage

death_analysis.sort_values(by=["Percent of Death Registered Compared to Population"], inplace=True)

death_analysis.head()
# Out:
#     Unnamed: 0          City  Total Population Land area (km2)[2]  \
# 52          89        AYLMER              7975                7.2
# 73         166      MARATHON              3022               4.33
# 24          34      INNISFIL             29464              23.71
# 49          85          KING              8396               14.2
# 30          45  WASAGA BEACH             22194              28.21
#
#     Total Deaths Registered Percent of Death Registered Compared to Population
# 52                       13                                              0.16%
# 73                        7                                              0.23%
# 24                       72                                              0.24%
# 49                       25                                              0.30%
# 30                       76                                              0.34%

# %% [markdown]
# Analysis 2 Conclusion- Comparing Population to Health Impacted by Oil Spills
#
# Top 5 Cities with Highest Health Impacted by Oil Spills - CHAPLEAU, RED LAKE, WIARTON, IROQUOIS FALLS, HEARST
#
# Top 5 Cities with Lowest Health Impacted by Oil Spills - TORONTO, KITCHENER, KINGSTON, OSHAWA, WELLAND

# %%
#Merge file and get the Percentage

spills_analysis = pd.merge(population_df, environment_spills_df, on='City')

spills_percent = ((spills_analysis['# of Health Impacts due to spills']) / (spills_analysis['Total Population']))

spills_analysis['Percent of Health Impacted by Oil Spills Compared to Population'] = spills_percent.astype(float).map("{:.4%}".format)

spills_analysis.head()
# Out:
#    Unnamed: 0       City  Total Population Land area (km2)[2]  \
# 0           0    TORONTO           5647656           1,829.05
# 1           1     OTTAWA           1068821             549.49
# 2           2   HAMILTON            729560             356.03
# 3           3  KITCHENER            522888             296.45
# 4           4     LONDON            423369             244.97
#
#    # of Health Impacts due to spills  \
# 0                                 43
# 1                                 15
# 2                                 13
# 3                                  4
# 4                                 13
#
#   Percent of Health Impacted by Oil Spills Compared to Population
# 0                                            0.0008%
# 1                                            0.0014%
# 2                                            0.0018%
# 3                                            0.0008%
# 4                                            0.0031%

# %%
#Sort by Highest Percentage

spills_analysis.sort_values(by=["Percent of Health Impacted by Oil Spills Compared to Population"], ascending=False, inplace=True)

spills_analysis.head()
# Out:
#     Unnamed: 0            City  Total Population Land area (km2)[2]  \
# 47         280        CHAPLEAU              1144               0.59
# 46         264        RED LAKE              1263               1.54
# 45         205         WIARTON              1996               2.36
# 44         174  IROQUOIS FALLS              2866               1.56
# 43         149          HEARST              3537               5.02
#
#     # of Health Impacts due to spills  \
# 47                                  1
# 46                                  1
# 45                                  1
# 44                                  1
# 43                                  1
#
#    Percent of Health Impacted by Oil Spills Compared to Population
# 47                                            0.0874%
# 46                                            0.0792%
# 45                                            0.0501%
# 44                                            0.0349%
# 43                                            0.0283%

# %%
#Sort by Lowest Percentage

spills_analysis.sort_values(by=["Percent of Health Impacted by Oil Spills Compared to Population"], inplace=True)

spills_analysis.head()
# Out:
#     Unnamed: 0       City  Total Population Land area (km2)[2]  \
# 0            0    TORONTO           5647656           1,829.05
# 3            3  KITCHENER            522888             296.45
# 10          11   KINGSTON            127943              83.43
# 5            5     OSHAWA            335949             159.79
# 15          19    WELLAND             69302              57.21
#
#     # of Health Impacts due to spills  \
# 0                                  43
# 3                                   4
# 10                                  1
# 5                                   3
# 15                                  1
#
#    Percent of Health Impacted by Oil Spills Compared to Population
# 0                                             0.0008%
# 3                                             0.0008%
# 10                                            0.0008%
# 5                                             0.0009%
# 15                                            0.0014%

# %% [markdown]
# Analysis 3 Conclusion - Comparing Population to Non-Compliant Facilities for Air Emission
#
# Top 5 Cities with Highest Non Compliant Air Facilities - SAULT STE. MARIE, KINGSTON, KENORA, SUDBURY, TIMMINS
#
# Top 5 Cities with Lowest Non Compliant Air Facilities  - TORONTO, LONDON, PETERBOROUGH, WINDSOR, BELLEVILLE

# %%
#Merge file and get the Percentage

air_emission_analysis = pd.merge(population_df, air_emission_df, on='City')

emission_percent = ((air_emission_analysis['# of Non Compliant Facilities for Air Emission']) / (air_emission_analysis['Total Population']))

air_emission_analysis['Percent of Non Compliant Facilities for Air Emission Compared to Population'] = emission_percent.astype(float).map("{:.5%}".format)

air_emission_analysis.head()
# Out:
#    Unnamed: 0      City  Total Population Land area (km2)[2]  \
# 0           0   TORONTO           5647656           1,829.05
# 1           2  HAMILTON            729560             356.03
# 2           4    LONDON            423369             244.97
# 3           6   WINDSOR            306519             184.96
# 4          11  KINGSTON            127943              83.43
#
#    # of Non Compliant Facilities for Air Emission  \
# 0                                               1
# 1                                              25
# 2                                               3
# 3                                               4
# 4                                              12
#
#   Percent of Non Compliant Facilities for Air Emission Compared to Population
# 0                                           0.00002%
# 1                                           0.00343%
# 2                                           0.00071%
# 3                                           0.00130%
# 4                                           0.00938%

# %%
#Sort by Highest Percentage

air_emission_analysis.sort_values(by=["Percent of Non Compliant Facilities for Air Emission Compared to Population"], ascending=False, inplace=True)

air_emission_analysis.head()
# Out:
#     Unnamed: 0              City  Total Population Land area (km2)[2]  \
# 10          20  SAULT STE. MARIE             64923              52.97
# 4           11          KINGSTON            127943              83.43
# 12          69            KENORA             10974              15.25
# 6           15           SUDBURY             92093              75.79
# 11          35           TIMMINS             28874              18.49
#
#     # of Non Compliant Facilities for Air Emission  \
# 10                                              34
# 4                                               12
# 12                                               1
# 6                                                7
# 11                                               2
#
#    Percent of Non Compliant Facilities for Air Emission Compared to Population
# 10                                           0.05237%
# 4                                            0.00938%
# 12                                           0.00911%
# 6                                            0.00760%
# 11                                           0.00693%

# %%
#Sort by Lowest Percentage

air_emission_analysis.sort_values(by=["Percent of Non Compliant Facilities for Air Emission Compared to Population"], inplace=True)

air_emission_analysis.head()
# Out:
#    Unnamed: 0          City  Total Population Land area (km2)[2]  \
# 0           0       TORONTO           5647656           1,829.05
# 2           4        LONDON            423369             244.97
# 7          16  PETERBOROUGH             84793              54.58
# 3           6       WINDSOR            306519             184.96
# 8          17    BELLEVILLE             75052              89.48
#
#    # of Non Compliant Facilities for Air Emission  \
# 0                                               1
# 2                                               3
# 7                                               1
# 3                                               4
# 8                                               1
#
#   Percent of Non Compliant Facilities for Air Emission Compared to Population
# 0                                           0.00002%
# 2                                           0.00071%
# 7                                           0.00118%
# 3                                           0.00130%
# 8                                           0.00133%

# %% [markdown]
# Analysis 4 Conclusion - Comparing Population to Social Assistance Programs Offered
#
# Top 5 Cities with Highest Social Assistance Programs Offered - ST. CATHARINES, PETERBOROUGH, BRANTFORD, THUNDER BAY, KINGSTON
#
# Top 5 Cities with Lowest Social Assistance Programs Offered - TORONTO, KITCHENER, OTTAWA, GUELPH, OSHAWA

# %%
#Merge file and get the Percentage

social_assistance_analysis = pd.merge(population_df, social_assistance_df, on='City')

social_percent = ((social_assistance_analysis['Social Assistance Programs Offered']) / (social_assistance_analysis['Total Population']))*100

social_assistance_analysis['Percent of Social Assistance Offered Compared to Population'] = social_percent
social_assistance_analysis.head()
# Out:
#    Unnamed: 0       City  Total Population Land area (km2)[2]  \
# 0           0    TORONTO           5647656           1,829.05
# 1           1     OTTAWA           1068821             549.49
# 2           2   HAMILTON            729560             356.03
# 3           3  KITCHENER            522888             296.45
# 4           4     LONDON            423369             244.97
#
#    Social Assistance Programs Offered  \
# 0                              478098
# 1                              102353
# 2                               91394
# 3                               49598
# 4                               69240
#
#    Percent of Social Assistance Offered Compared to Population
# 0                                           8.465424
# 1                                           9.576253
# 2                                          12.527277
# 3                                           9.485396
# 4                                          16.354528

# %%
#Sort by Highest Percentage

social_assistance_analysis.sort_values(by=["Percent of Social Assistance Offered Compared to Population"], ascending=False, inplace=True)

social_assistance_analysis.head()
# Out:
#     Unnamed: 0            City  Total Population Land area (km2)[2]  \
# 7            7  ST. CATHARINES            242460             140.59
# 13          16    PETERBOROUGH             84793              54.58
# 11          13       BRANTFORD            104413              62.13
# 12          14     THUNDER BAY             95266              76.03
# 10          11        KINGSTON            127943              83.43
#
#     Social Assistance Programs Offered  \
# 7                                62570
# 13                               20225
# 11                               22672
# 12                               20659
# 10                               27577
#
#     Percent of Social Assistance Offered Compared to Population
# 7                                           25.806319
# 13                                          23.852205
# 11                                          21.713771
# 12                                          21.685596
# 10                                          21.554130

# %%
#Sort by Lowest Percentage

social_assistance_analysis.sort_values(by=["Percent of Social Assistance Offered Compared to Population"], inplace=True)

social_assistance_analysis.head()
# Out:
#    Unnamed: 0       City  Total Population Land area (km2)[2]  \
# 0           0    TORONTO           5647656           1,829.05
# 3           3  KITCHENER            522888             296.45
# 1           1     OTTAWA           1068821             549.49
# 9           9     GUELPH            144356              79.57
# 5           5     OSHAWA            335949             159.79
#
#    Social Assistance Programs Offered  \
# 0                              478098
# 3                               49598
# 1                              102353
# 9                               14088
# 5                               40624
#
#    Percent of Social Assistance Offered Compared to Population
# 0                                           8.465424
# 3                                           9.485396
# 1                                           9.576253
# 9                                           9.759206
# 5                                          12.092312

# %% [markdown]
# Analysis 5 Conclusion - Comparing Population to University Enrolment
#
# Top 5 Cities with Highest University Enrolment - PETERBOROUGH, KINGSTON, GUELPH, LONDON, SUDBURY
#
# Top 5 Cities with Lowest University Enrolment - TORONTO, SAULT STE. MARIE, OSHAWA, OTTAWA, HEARST

# %%
#Merge file and get the Percentage

univ_analysis = pd.merge(population_df, university_df, on='City')

univ_percent = (univ_analysis['Total Enrollment']) / (univ_analysis['Total Population']) * 100

univ_analysis['Percent of University Enrolment Compared to Population'] = univ_percent

univ_analysis.head()
# Out:
#    Unnamed: 0      City  Total Population Land area (km2)[2]  \
# 0           0   TORONTO           5647656           1,829.05
# 1           1    OTTAWA           1068821             549.49
# 2           2  HAMILTON            729560             356.03
# 3           4    LONDON            423369             244.97
# 4           5    OSHAWA            335949             159.79
#
#    2020-2021 (Undergrad)  2020-2021 (Graduate)  Total Enrollment  \
# 0                 100007                 12315            112322
# 1                  30402                  4399             34801
# 2                  30560                  4215             34775
# 3                  32132                  6212             38344
# 4                   9152                   546              9698
#
#    Percent of University Enrolment Compared to Population
# 0                                           1.988825
# 1                                           3.256018
# 2                                           4.766572
# 3                                           9.056875
# 4                                           2.886748

# %%
#Sort by Highest Percentage

univ_analysis.sort_values(by=["Percent of University Enrolment Compared to Population"], ascending=False, inplace=True)

univ_analysis.head()
# Out:
#     Unnamed: 0          City  Total Population Land area (km2)[2]  \
# 11          16  PETERBOROUGH             84793              54.58
# 8           11      KINGSTON            127943              83.43
# 7            9        GUELPH            144356              79.57
# 3            4        LONDON            423369             244.97
# 10          15       SUDBURY             92093              75.79
#
#     2020-2021 (Undergrad)  2020-2021 (Graduate)  Total Enrollment  \
# 11                  68002                 19055             87057
# 8                   32614                  6455             39069
# 7                   23998                  2834             26832
# 3                   32132                  6212             38344
# 10                   6783                   709              7492
#
#     Percent of University Enrolment Compared to Population
# 11                                         102.670032
# 8                                           30.536254
# 7                                           18.587381
# 3                                            9.056875
# 10                                           8.135255

# %%
#Sort by Lowest Percentage

univ_analysis.sort_values(by=["Percent of University Enrolment Compared to Population"], inplace=True)

univ_analysis.head()
# Out:
#     Unnamed: 0              City  Total Population Land area (km2)[2]  \
# 0            0           TORONTO           5647656           1,829.05
# 12          20  SAULT STE. MARIE             64923              52.97
# 4            5            OSHAWA            335949             159.79
# 1            1            OTTAWA           1068821             549.49
# 14         149            HEARST              3537               5.02
#
#     2020-2021 (Undergrad)  2020-2021 (Graduate)  Total Enrollment  \
# 0                  100007                 12315            112322
# 12                   1412                     0              1412
# 4                    9152                   546              9698
# 1                   30402                  4399             34801
# 14                    162                     0               162
#
#     Percent of University Enrolment Compared to Population
# 0                                            1.988825
# 12                                           2.174884
# 4                                            2.886748
# 1                                            3.256018
# 14                                           4.580153
