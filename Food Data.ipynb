# %%
# Import Dependencies
import pandas as pd

# %%
jan = "FoodResources/food_index_jan.csv"
feb = "FoodResources/food_index_feb.csv"
march = "FoodResources/food_index_march.csv"
april = "FoodResources/food_index_april.csv"
may = "FoodResources/food_index_may.csv"
june = "FoodResources/food_index_june.csv"
july = "FoodResources/food_index_july.csv"
aug = "FoodResources/food_index_aug.csv"
sept = "FoodResources/food_index_sept.csv"
october = "FoodResources/food_index_october.csv"
nov = "FoodResources/food_index_nov.csv"
dec = "FoodResources/food_index_dec.csv"

# %%
#jan_df = pd.read_csv(jan,encoding='ISO-8859-1')

# %%
#jan_df.head(20)

# %%
#feb_df = pd.read_csv(feb,encoding='ISO-8859-1')
#feb_df.head(20)

# %%
#mar_df = pd.read_csv(march,encoding='ISO-8859-1')
#mar_df.head(20)

# %%
#apr_df = pd.read_csv(april,encoding='ISO-8859-1')
#apr_df.head(20)

# %%
#may_df = pd.read_csv(may,encoding='ISO-8859-1')
#may_df.head(20)

# %%
#june_df = pd.read_csv(june,encoding='ISO-8859-1')
#june_df.head(20)

# %%
july_df = pd.read_csv(july,encoding='ISO-8859-1')
july_df.head(20)
# Out:
#                       Products and product groups 3 4 July 2021 June 2022  \
# 0                                                 NaN  2002=100       NaN
# 1                                              Food 5     159.2     173.2
# 2                          Food purchased from stores     157.2     172.2
# 3                                                Meat     180.1     193.1
# 4            Fresh or frozen meat (excluding poultry)     180.5     194.0
# 5                                Fresh or frozen beef     196.4     213.7
# 6                                Fresh or frozen pork     140.5     143.1
# 7                             Fresh or frozen poultry     184.7     197.3
# 8                             Fresh or frozen chicken     187.8     201.8
# 9                                      Processed meat     174.6     187.6
# 10                                      Ham and bacon        ..        ..
# 11                               Other processed meat        ..        ..
# ...

# %%
aug_df = pd.read_csv(aug,encoding='ISO-8859-1')
aug_df.head(20)
# Out:
#                       Products and product groups 3 4 August 2021 July 2022  \
# 0                                                 NaN    2002=100       NaN
# 1                                              Food 5       160.0     174.6
# 2                          Food purchased from stores       157.8     173.4
# 3                                                Meat       183.2     193.0
# 4            Fresh or frozen meat (excluding poultry)       181.0     195.6
# 5                                Fresh or frozen beef       197.1     214.6
# 6                                Fresh or frozen pork       140.9     146.6
# 7                             Fresh or frozen poultry       193.9     185.2
# 8                             Fresh or frozen chicken       197.4     188.3
# 9                                      Processed meat       176.0     194.5
# 10                                      Ham and bacon          ..        ..
# ...

# %%
sept_df = pd.read_csv(sept,encoding='ISO-8859-1')
sept_df.head(20)
# Out:
#                       Products and product groups 3 4 September 2021  \
# 0                                                 NaN       2002=100
# 1                                              Food 5          160.3
# 2                          Food purchased from stores          158.2
# 3                                                Meat          183.9
# 4            Fresh or frozen meat (excluding poultry)          183.6
# 5                                Fresh or frozen beef          200.6
# 6                                Fresh or frozen pork          141.7
# 7                             Fresh or frozen poultry          191.3
# 8                             Fresh or frozen chicken          194.3
# 9                                      Processed meat          177.1
# 10                                      Ham and bacon             ..
# 11                               Other processed meat             ..
# 12            Fish, seafood and other marine products          147.5
# ...

# %%
oct_df = pd.read_csv(october,encoding='ISO-8859-1')
oct_df.head(20)
# Out:
#                       Products and product groups 3 4 October 2021  \
# 0                                                 NaN     2002=100
# 1                                              Food 5        160.6
# 2                          Food purchased from stores        158.2
# 3                                                Meat        183.8
# 4            Fresh or frozen meat (excluding poultry)        184.8
# 5                                Fresh or frozen beef        207.2
# 6                                Fresh or frozen pork        140.1
# 7                             Fresh or frozen poultry        186.9
# 8                             Fresh or frozen chicken        192.5
# 9                                      Processed meat        178.9
# 10                                      Ham and bacon           ..
# 11                               Other processed meat           ..
# 12            Fish, seafood and other marine products        152.2
# ...

# %%
nov_df = pd.read_csv(nov,encoding='ISO-8859-1')
nov_df.head(20)
# Out:
#                       Products and product groups 3 4 November 2021  \
# 0                                                 NaN      2002=100
# 1                                              Food 5         162.8
# 2                          Food purchased from stores         160.9
# 3                                                Meat         184.6
# 4            Fresh or frozen meat (excluding poultry)         187.8
# 5                                Fresh or frozen beef         205.9
# 6                                Fresh or frozen pork         142.7
# 7                             Fresh or frozen poultry         182.6
# 8                             Fresh or frozen chicken         184.5
# 9                                      Processed meat         181.0
# 10                                      Ham and bacon            ..
# 11                               Other processed meat            ..
# 12            Fish, seafood and other marine products         149.3
# ...

# %%
dec_df = pd.read_csv(dec,encoding='ISO-8859-1')
dec_df.head(20)
# Out:
#                       Products and product groups 3 4 December 2021  \
# 0                                                 NaN      2002=100
# 1                                              Food 5         164.1
# 2                          Food purchased from stores         162.3
# 3                                                Meat         185.5
# 4            Fresh or frozen meat (excluding poultry)         188.9
# 5                                Fresh or frozen beef         207.4
# 6                                Fresh or frozen pork         143.8
# 7                             Fresh or frozen poultry         181.4
# 8                             Fresh or frozen chicken         183.8
# 9                                      Processed meat         183.3
# 10                                      Ham and bacon            ..
# 11                               Other processed meat            ..
# 12            Fish, seafood and other marine products         150.8
# ...
