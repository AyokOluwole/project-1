# %%
#dependencies
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import csv
import requests
from scipy.stats import linregress
import json

# %%
url = "https://services9.arcgis.com/a03W7iZ8T3s5vB7p/arcgis/rest/services/MOH_SERVICE_LOCATION/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson"

# %%
print(requests.get(url))
# Out:
# <Response [200]>

# %%
response = (requests.get(url).json())
response
# Out:
# {'type': 'FeatureCollection',
#  'properties': {'exceededTransferLimit': True},
#  'features': [{'type': 'Feature',
#    'id': 1,
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.1950090790824, 42.7792359451999]},
#    'properties': {'FID': 1,
#     'OGF_ID': 172382629,
#     'MOH_PRO_ID': '4120276',
#     'SERV_TYPE': 'Pharmacy',
#     'SERV_DET': 'RP',
#     'EN_NAME': 'St Thomas Medical Pharmacy',
#     'FR_NAME': ' ',
#     'EN_ALT': ' ',
#     'FR_ALT': ' ',
#     'ADDRESS_1': '475 Talbot Street',
#     'ADDRESS_2': ' ',
#     'ADDR_DESCR': ' ',
#     'COMMUNITY': 'St. Thomas',
#     'POSTALCODE': 'N5P1C1',
#     'GEO_UPT_DT': '20220428140105',
#     'EFF_DATE': '20220426153448'}},
#   {'type': 'Feature',
#    'id': 2,
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.0989964368871, 43.9299712996578]},
#    'properties': {'FID': 2,
#     'OGF_ID': 172379313,
#     'MOH_PRO_ID': '3800',
#     'SERV_TYPE': 'Laboratory - Specimen Collection Centre',
# ...

# %%
print(df)
#service_type = (response["SERV_TYPE"])
#service_type
#service_det = response["SERV"]["DET"]
#community = response["COMMUNITY"]
    
#service_data=pd.DataFrame({"Service": service_type, 
                     #"Department": service_det,
                     #"City": city})

#service_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5856\2904146739.py in <module>
#       1 response = requests.get(url)
#       2 dictr = response.json()
# ----> 3 recs = dictr['result']['records']
#       4 df = json_normalize(recs)
#       5 print(df)
#
# KeyError: 'result'

# %%
df = pd.DataFrame(responce)
df
