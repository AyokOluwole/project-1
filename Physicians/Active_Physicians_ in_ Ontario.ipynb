# %%
# Dependencies
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
# File to Load
file = "../Physicians/Physicians.csv"

# %%
# read physicians File and store into Pandas DataFrames
df = pd.read_csv(file)

df.head()
# Out:
#   County Name                         csd_name  Family Medicine  Specialist  \
# 0      Algoma  Algoma, Unorganized, North Part                1         NaN
# 1      Algoma                      Blind River                8         1.0
# 2      Algoma                      Elliot Lake               16         2.0
# 3      Algoma                  Garden River 14                1         NaN
# 4      Algoma                       Hornepayne                3         NaN
#
#    Grand Total
# 0            1
# 1            9
# 2           18
# 3            1
# 4            3

# %%
#fill nan with value
clean_data = df.fillna(0)
clean_data.head()
# Out:
#   County Name                         csd_name  Family Medicine  Specialist  \
# 0      Algoma  Algoma, Unorganized, North Part                1         0.0
# 1      Algoma                      Blind River                8         1.0
# 2      Algoma                      Elliot Lake               16         2.0
# 3      Algoma                  Garden River 14                1         0.0
# 4      Algoma                       Hornepayne                3         0.0
#
#    Grand Total
# 0            1
# 1            9
# 2           18
# 3            1
# 4            3

# %%
#number of county in daataset
County =len(clean_data['County Name'].value_counts())
County
# Out:
# 49

# %%
#extracting county name and csd_name columns 
organized_df = clean_data[['County Name', 'csd_name']]
organized_df.head()
# Out:
#   County Name                         csd_name
# 0      Algoma  Algoma, Unorganized, North Part
# 1      Algoma                      Blind River
# 2      Algoma                      Elliot Lake
# 3      Algoma                  Garden River 14
# 4      Algoma                       Hornepayne

# %%
#group by County Name
county_dataframe = clean_data.set_index('csd_name').groupby(['County Name'])
county_dataframe

# %%
#total number of family_medicine per county
family_medicine_df = county_dataframe["Family Medicine"].sum()
family_medicine_df.head()
# Out:
# County Name
# Algoma          140
# Brant           149
# Bruce            73
# Chatham-Kent     86
# Cochrane        106
# Name: Family Medicine, dtype: int64

# %%
##total number of Specialist per county
Specialist_df = county_dataframe["Specialist"].sum()
Specialist_df.head()
# Out:
# County Name
# Algoma           95.0
# Brant           118.0
# Bruce             2.0
# Chatham-Kent     68.0
# Cochrane         42.0
# Name: Specialist, dtype: float64

# %%
#merge dataset to get total_physicians per county
total_physicians=pd.merge(Specialist_df,family_medicine_df,on=["County Name"])
total_physicians.head()
# Out:
#               Specialist  Family Medicine
# County Name
# Algoma              95.0              140
# Brant              118.0              149
# Bruce                2.0               73
# Chatham-Kent        68.0               86
# Cochrane            42.0              106

# %%
csd_dataframe = clean_data.set_index('csd_name')
csd_dataframe.head()
# Out:
#                                 County Name  Family Medicine  Specialist  \
# csd_name
# Algoma, Unorganized, North Part      Algoma                1         0.0
# Blind River                          Algoma                8         1.0
# Elliot Lake                          Algoma               16         2.0
# Garden River 14                      Algoma                1         0.0
# Hornepayne                           Algoma                3         0.0
#
#                                  Grand Total
# csd_name
# Algoma, Unorganized, North Part            1
# Blind River                                9
# Elliot Lake                               18
# Garden River 14                            1
# Hornepayne                                 3

# %%
final_df = pd.merge(csd_dataframe,total_physicians,how="left",on=["County Name","County Name"])
final_df.rename(columns={'Specialist_y':'Total_specialist_per_county','Family Medicine_y':'Total_family_medicine_per_county'}, inplace=True)
final_df.head()
# Out:
#   County Name  Family Medicine_x  Specialist_x  Grand Total  \
# 0      Algoma                  1           0.0            1
# 1      Algoma                  8           1.0            9
# 2      Algoma                 16           2.0           18
# 3      Algoma                  1           0.0            1
# 4      Algoma                  3           0.0            3
#
#    Total_specialist_per_county  Total_family_medicine_per_county
# 0                         95.0                               140
# 1                         95.0                               140
# 2                         95.0                               140
# 3                         95.0                               140
# 4                         95.0                               140

# %%
final_data = pd.merge(final_df,organized_df,how="left",on=["County Name","County Name"])
final_data.head()
# Out:
#   County Name  Family Medicine_x  Specialist_x  Grand Total  \
# 0      Algoma                  1           0.0            1
# 1      Algoma                  1           0.0            1
# 2      Algoma                  1           0.0            1
# 3      Algoma                  1           0.0            1
# 4      Algoma                  1           0.0            1
#
#    Total_specialist_per_county  Total_family_medicine_per_county  \
# 0                         95.0                               140
# 1                         95.0                               140
# 2                         95.0                               140
# 3                         95.0                               140
# 4                         95.0                               140
#
#                           csd_name
# 0  Algoma, Unorganized, North Part
# 1                      Blind River
# 2                      Elliot Lake
# 3                  Garden River 14
# 4                       Hornepayne

# %%
complete_data = final_data.set_index('csd_name')
complete_data
# Out:
#                                 County Name  Family Medicine_x  Specialist_x  \
# csd_name
# Algoma, Unorganized, North Part      Algoma                  1           0.0
# Blind River                          Algoma                  1           0.0
# Elliot Lake                          Algoma                  1           0.0
# Garden River 14                      Algoma                  1           0.0
# Hornepayne                           Algoma                  1           0.0
# ...                                     ...                ...           ...
# Markham                                York                 24           3.0
# Newmarket                              York                 24           3.0
# Richmond Hill                          York                 24           3.0
# Vaughan                                York                 24           3.0
# Whitchurch-Stouffville                 York                 24           3.0
#
#                                  Grand Total  Total_specialist_per_county  \
# csd_name
# Algoma, Unorganized, North Part            1                         95.0
# Blind River                                1                         95.0
# Elliot Lake                                1                         95.0
# Garden River 14                            1                         95.0
# Hornepayne                                 1                         95.0
# ...                                      ...                          ...
# Markham                                   27                       1013.0
# Newmarket                                 27                       1013.0
# Richmond Hill                             27                       1013.0
# Vaughan                                   27                       1013.0
# Whitchurch-Stouffville                    27                       1013.0
#
#                                  Total_family_medicine_per_county
# csd_name
# Algoma, Unorganized, North Part                               140
# Blind River                                                   140
# Elliot Lake                                                   140
# Garden River 14                                               140
# Hornepayne                                                    140
# ...                                                           ...
# Markham                                                      1064
# Newmarket                                                    1064
# Richmond Hill                                                1064
# Vaughan                                                      1064
# Whitchurch-Stouffville                                       1064
#
# [2136 rows x 6 columns]
