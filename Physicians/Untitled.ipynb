# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
file = "../Physicians/health_service.csv"

# %%
df = pd.read_csv(file)

df.head()
# Out:
#            X          Y  FID     Ogf_Id  MOH_PRO_ID  \
# 0 -81.195009  42.779236    1  172382629     4120276
# 1 -80.098996  43.929971    2  172379313        3800
# 2 -79.543791  43.752078    3  172387403  9000000197
# 3 -79.716237  44.328811    4  172384809     7185994
# 4 -79.488756  43.723780    5  172383830     5947595
#
#                               Service_type  \
# 0                                 Pharmacy
# 1  Laboratory - Specimen Collection Centre
# 2              Senior Active Living Centre
# 3                                 Pharmacy
# 4                                 Pharmacy
#
#                                 Service_det  \
# 0                                        RP
# 1  Specimen Collection Centre - Private SCC
# 2
# 3                                        RP
# 4                                        RP
#
#                                           EN_NAME  \
# 0                      St Thomas Medical Pharmacy
# ...

# %%
df.dtypes
# Out:
# X               float64
# Y               float64
# FID               int64
# Ogf_Id            int64
# MOH_PRO_ID       object
# Service_type     object
# Service_det      object
# EN_NAME          object
# FR_NAME          object
# EN_ALT           object
# FR_ALT           object
# ADDRESS_1        object
# ADDRESS_2        object
# ADDR_DESCR       object
# Community        object
# POSTALCODE       object
# GEO_UPT_DT        int64
# EFF_DATE          int64
# dtype: object

# %%
Service_type = df(['Service_type']['Community'])
Service_type
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17756\3033181709.py in <module>
# ----> 1 Service_type = df(['Service_type']['Community'])
#       2 Service_type
#
# TypeError: list indices must be integers or slices, not str

# %%
Service_type_df = pd.DataFrame({"health_service": Service_type,
                                  "city": Community})
Service_type_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17756\3411835221.py in <module>
#       1 Service_type_df = pd.DataFrame({"health_service": Service_type,
# ----> 2                                   "city": Community})
#       3 Service_type_df
#
# NameError: name 'Community' is not defined
