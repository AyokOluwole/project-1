# %%
import pandas as pd

# %%
# Store filepath in a variable
infra_proj = "../Project/Resources/Raw_Data/Ont_infrastructure.csv"

# %%
# Read the Data file with the pandas library
infra_proj_df = pd.read_csv(infra_proj)

infra_proj_df.head(3)
# Out:
#       Category                      Supporting Ministry          Community  \
# 0   Recreation                           Infrastructure  ADJALA-TOSORONTIO
# 1   Recreation               Tourism, Culture and Sport  ADJALA-TOSORONTIO
# 2  Communities  Children, Community and Social Services               AJAX
#
#                                              Project              Status  \
# 0  Accessibility Upgrades to Three Municipal Publ...            Planning
# 1                               Adjala-Tosorontio Tp  Under construction
# 2                        Grandview Children's Centre  Under construction
#
#   Target Completion Date                                        Description  \
# 0                   2022  The project will upgrade accessibility at thre...
# 1                 23-Apr  Our Municipality, with a $498,200 Community Bu...
# 2                 24-May  New construction of a children's treatment cen...
#
#                                               Result    Area   Region  ...  \
# 0                                                NaN  SIMCOE  Central  ...
# 1                                                NaN  SIMCOE  Central  ...
# 2  The new centre will create more treatment spac...  DURHAM  Central  ...
#
#   Highway / Transit Line Estimated Total Budget Municipal Funding  \
# 0                    NaN              $295,275                Yes
# 1                    NaN              $498,200                NaN
# 2                    NaN           $31,000,000                NaN
#
#   Provincial Funding Federal Funding Other Funding  \
# 0                Yes             Yes           NaN
# 1                Yes             NaN           NaN
# 2                Yes             Yes           Yes
#
#                                              Website   Latitude   Longitude  \
# 0  https://www.news.ontario.ca/en/release/61048/3...  44.246169  -80.021502
# 1                                                NaN  44.046227  -79.891169
# 2  https://www.news.ontario.ca/en/backgrounder/52...     43.879      -79.03
#
#   Geometry
# 0      NaN
# 1      NaN
# 2      NaN
#
# [3 rows x 22 columns]

# %%
#Keep the required Columns
organized_df = infra_proj_df[['Community', 'Category']]

organized_df = organized_df.rename(columns= {'Community': 'City', 'Category': '# of Planned Infrastructure Projects' })

organized_df.head()
# Out:
#                 City # of Planned Infrastructure Projects
# 0  ADJALA-TOSORONTIO                           Recreation
# 1  ADJALA-TOSORONTIO                           Recreation
# 2               AJAX                          Communities
# 3               AJAX                           Child care
# 4               AJAX                           Child care

# %%
#Group by Cities and sum the categories
grouped_df = organized_df.groupby(['City']).count()

sorted_df = grouped_df.sort_values(['# of Planned Infrastructure Projects'], ascending=False)

sorted_df.head()
# Out:
#              # of Planned Infrastructure Projects
# City
# TORONTO                                       224
# OTTAWA                                         54
# MISSISSAUGA                                    51
# ONTARIO                                        49
# HAMILTON                                       36

# %%
#Save the final copy to CSV
sorted_df.to_csv("../Project/Resources/Cleaned_Data/Infrastructure_Projects.csv")
