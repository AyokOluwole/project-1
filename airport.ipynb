# %%
# Import the required libraries
import hvplot.pandas
import pandas as pd
import numpy as np


# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
load = "resources/doc.csv"

# %%
newair = pd.read_csv(load)
newair.head(10)
# Out:
#                                              name  Snippet  \
# 0                            Peterborough Airport      NaN
# 1                    London International Airport      NaN
# 2  Ottawa Macdonald-Cartier International Airport      NaN
# 3               Thunder Bay International Airport      NaN
# 4           Toronto Pearson International Airport      NaN
# 5                                Alliston Airport      NaN
# 6                               Armstrong Airport      NaN
# 7        Arnprior/South Renfrew Municipal Airport      NaN
# 8                            Attawapiskat Airport      NaN
# 9                          Atwood/Coghlin Airport      NaN
#
#                                          description  longitude   latitude  \
# 0  <br>Source: Wikipedia article <a href="https:/... -78.363333  44.230556
# 1  <br>Source: Wikipedia article <a href="https:/... -81.151111  43.033056
# 2  <br>Source: Wikipedia article <a href="https:/... -75.669167  45.322500
# ...

# %%
newai_df = newair[[ 'name', 'longitude','latitude']]

newai_df.head(10)
# Out:
#                                              name  longitude   latitude
# 0                            Peterborough Airport -78.363333  44.230556
# 1                    London International Airport -81.151111  43.033056
# 2  Ottawa Macdonald-Cartier International Airport -75.669167  45.322500
# 3               Thunder Bay International Airport -89.323889  48.371944
# 4           Toronto Pearson International Airport -79.630556  43.677222
# 5                                Alliston Airport -79.833333  44.183333
# 6                               Armstrong Airport -88.910000  50.293889
# 7        Arnprior/South Renfrew Municipal Airport -76.365833  45.413611
# 8                            Attawapiskat Airport -82.431944  52.927500
# 9                          Atwood/Coghlin Airport -81.004444  43.683333

# %%
newap_df = newai_df.rename(columns={'name': 'Airport Name'})
newap_df.head(10)
# Out:
#                                      Airport Name  longitude   latitude
# 0                            Peterborough Airport -78.363333  44.230556
# 1                    London International Airport -81.151111  43.033056
# 2  Ottawa Macdonald-Cartier International Airport -75.669167  45.322500
# 3               Thunder Bay International Airport -89.323889  48.371944
# 4           Toronto Pearson International Airport -79.630556  43.677222
# 5                                Alliston Airport -79.833333  44.183333
# 6                               Armstrong Airport -88.910000  50.293889
# 7        Arnprior/South Renfrew Municipal Airport -76.365833  45.413611
# 8                            Attawapiskat Airport -82.431944  52.927500
# 9                          Atwood/Coghlin Airport -81.004444  43.683333

# %%
# Configure the map
ontario_airports = newap_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600, 
    hover_cols = ["Airport Name"], 
    color = "Airport Name"


)

# Display the map plot
ontario_airports
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (Airport Name)
