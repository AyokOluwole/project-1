# %%
# Import Dependencies
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
commuting_by_income = "commuting_by_employment_income.csv"

# %%
commuting_by_income_df = pd.read_csv(commuting_by_income, encoding="utf-8")

# %%
commuting_by_income_df.head(20)
# Out:
#        Main mode of commuting (11A) 4 Total - Main mode of commuting 6  \
# 0     Employment income groups (18) 5                              NaN
# 1           Total - Employment income                        4,533,390
# 2           Without employment income                          230,200
# 3              With employment income                        4,303,190
# 4   Percentage with employment income                             94.9
# 5       Under $5,000 (including loss)                          285,300
# 6                    $5,000 to $9,999                          279,090
# 7                  $10,000 to $19,999                          483,200
# 8                  $20,000 to $29,999                          430,980
# 9                  $30,000 to $39,999                          468,840
# 10                 $40,000 to $49,999                          463,765
# 11                 $50,000 to $59,999                          409,345
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3b/cl89mzy547n81hm0vjss6q9w0000gn/T/ipykernel_25650/1377291968.py in <module>
# ----> 1 commute_chart = commuting_by_income_df.plot(kind='bar', figsize=(6,8))
#       2
#       3 # Set the xlabel and ylabel using class methods
#       4 count_chart.set_xlabel("Road Type")
#       5 count_chart.set_ylabel("Number of Accidents")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
# ...
